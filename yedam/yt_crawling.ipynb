# %%
import requests
import isodate
import os
import re
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# API 키 가져오기
load_dotenv()
API_KEY = os.getenv("API_KEY")

# 검색 기간: 현재로부터 한 달 전 ~ 현재
current_date_obj = datetime.now(timezone.utc)
one_month_ago = current_date_obj - timedelta(days=30)
start_date = one_month_ago.isoformat()
end_date = current_date_obj.isoformat()

# ISO8601 duration 변환 및 4분 이상 영상만 허용 (240초)
def convert_duration_to_seconds(duration):
    try:
        parsed_duration = isodate.parse_duration(duration)
        seconds = int(parsed_duration.total_seconds()) if parsed_duration else 0
        return seconds if seconds >= 240 else 0
    except Exception as e:
        print(f"Duration 변환 오류: {e}")
        return 0

# 한국어 포함 여부 확인 함수
def contains_korean(text):
    return bool(re.search(r"[가-힣]", text))

# 카테고리 설정 (예: Film & Animation은 1)
category_id = 1

# 검색 API를 통해 모든 페이지의 영상 ID를 수집 (검색 조건에 맞는 영상만, 한국어 제목 포함)
def search_video_ids(category_id):
    search_url = "https://www.googleapis.com/youtube/v3/search"
    params = {
        "part": "snippet",
        "type": "video",
        "regionCode": "KR",
        "videoCategoryId": category_id,
        "order": "viewCount",
        "maxResults": 50,  # 최대 허용값
        "publishedAfter": start_date,
        "publishedBefore": end_date,
        "relevanceLanguage": "ko",
        "key": API_KEY,
    }
    
    video_ids = set()
    next_page_token = None
    while True:
        if next_page_token:
            params["pageToken"] = next_page_token
        response = requests.get(search_url, params=params)
        if response.status_code != 200:
            print(f"[카테고리 {category_id}] API 호출 실패: {response.text}")
            break
        data = response.json()
        for item in data.get("items", []):
            vid = item.get("id", {}).get("videoId")
            title = item.get("snippet", {}).get("title", "")
            if vid and contains_korean(title):
                video_ids.add(vid)
        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break
    return list(video_ids)

# 영상 세부 정보를 가져오기
def get_videos_details(video_ids):
    url = "https://www.googleapis.com/youtube/v3/videos"
    all_videos = []
    
    for i in range(0, len(video_ids), 50):
        batch = video_ids[i:i+50]
        params = {
            "part": "snippet,statistics,contentDetails",
            "id": ",".join(batch),
            "key": API_KEY,
        }
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"API 호출 오류: {response.text}")
            continue
        data = response.json()
        all_videos.extend(data.get("items", []))
    
    return all_videos

# 채널 정보를 가져오기
def get_channels_info(channel_ids):
    url = "https://www.googleapis.com/youtube/v3/channels"
    all_channels = []
    channel_ids = list(channel_ids)
    
    for i in range(0, len(channel_ids), 50):
        batch = channel_ids[i:i+50]
        params = {
            "part": "snippet,statistics",
            "id": ",".join(batch),
            "key": API_KEY,
        }
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"get_channels_info 호출 오류: {response.text}")
            continue
        data = response.json()
        all_channels.extend(data.get("items", []))
    
    return all_channels

# --- 메인 데이터 수집 ---
video_data = []
channel_ids = set()

print(f"카테고리 ID {category_id} (Film & Animation)에서 영상 수집 중...")
video_ids = search_video_ids(category_id)
print(f"검색된 영상 수: {len(video_ids)}")

if not video_ids:
    print(f"[카테고리 {category_id}] 조건에 맞는 영상이 없습니다.")
else:
    videos_details = get_videos_details(video_ids)
    print(f"상세 정보 가져온 영상 수: {len(videos_details)}")
    
    # 각 영상별로 조건에 맞는 데이터만 수집
    for video in videos_details:
        snippet = video.get("snippet", {})
        statistics = video.get("statistics", {})
        content_details = video.get("contentDetails", {})

        video_id = video.get("id")
        channel_id = snippet.get("channelId", "")
        title = snippet.get("title", "")
        view_count = int(statistics.get("viewCount", "0"))
        like_count = statistics.get("likeCount", "0")
        comment_count = statistics.get("commentCount", "0")
        upload_date = snippet.get("publishedAt", "")
        duration_sec = convert_duration_to_seconds(content_details.get("duration", "PT0S"))
        thumbnail_url = snippet.get("thumbnails", {}).get("high", {}).get("url", "")
        tags = snippet.get("tags", [])

        if duration_sec == 0:
            continue

        video_data.append([
            video_id, category_id, channel_id, title, view_count, like_count, comment_count, 
            upload_date, duration_sec, tags, thumbnail_url
        ])
        
        channel_ids.add(channel_id)

# 채널 정보 수집
channel_data = []
channels_details = get_channels_info(channel_ids)
for channel in channels_details:
    snippet = channel.get("snippet", {})
    statistics = channel.get("statistics", {})
    
    channel_data.append([
        channel.get("id"), snippet.get("title", ""), statistics.get("subscriberCount", "0"),
        statistics.get("viewCount", "0"), statistics.get("videoCount", "0")
    ])

# 데이터 저장 (CSV 파일로 저장)
df_videos = pd.DataFrame(video_data, columns=["videoID", "categoryID", "channelID", "title", "viewCount", "likeCount", "commentCount", "uploadDate", "duration", "tags", "thumbnailURL"])
df_videos.to_csv("videos_1.csv", index=False, encoding="utf-8-sig")
print("영상 데이터 저장 완료: videos_1.csv")

df_channels = pd.DataFrame(channel_data, columns=["channelID", "channelTitle", "subscriberCount", "totalViews", "videosCount"])
df_channels.to_csv("channel_1.csv", index=False, encoding="utf-8-sig")
print("채널 데이터 저장 완료: channel_1.csv")

print("완료!")
# Out:
# 카테고리 ID 1 (Film & Animation)에서 영상 수집 중...
# 검색된 영상 수: 251
# 상세 정보 가져온 영상 수: 251
# 영상 데이터 저장 완료: videos_1.csv
# 채널 데이터 저장 완료: channel_1.csv
# 완료!

# %% [markdown]
# ### 4분 이상 영상만 크롤링

# %%
import requests
import isodate
import os
import re
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# API 키 여러 개 로드
load_dotenv()

def load_api_keys():
    keys = []
    i = 1
    while True:
        key = os.getenv(f"API_KEY{i}")
        if key:
            keys.append(key)
            i += 1
        else:
            break
    return keys

api_keys = load_api_keys()
key_index = 0

def get_valid_response(url, params):
    global key_index
    max_attempts = len(api_keys)
    for _ in range(max_attempts):
        params["key"] = api_keys[key_index]
        response = requests.get(url, params=params)
        if response.status_code == 200:
            return response
        elif response.status_code in [403, 400]:  # 할당량 초과
            print(f"[!] 키 {key_index+1} 한도 초과. 다음 키로 전환.")
            key_index = (key_index + 1) % len(api_keys)
        else:
            print(f"[!] 기타 오류: {response.text}")
            break
    print("[X] 모든 API 키가 소진되었거나 요청 실패.")
    return None

# 날짜 설정
current_date_obj = datetime.now(timezone.utc)
one_month_ago = current_date_obj - timedelta(days=30)
start_date = one_month_ago.isoformat()
end_date = current_date_obj.isoformat()

# CSV에서 키워드 불러오기
keywords_df = pd.read_csv("유튜브 카테고리명.csv")
keywords = keywords_df['category'].dropna().unique().tolist()

# 유틸 함수들
def convert_duration_to_seconds(duration):
    try:
        parsed_duration = isodate.parse_duration(duration)
        seconds = int(parsed_duration.total_seconds()) if parsed_duration else 0
        return seconds if seconds >= 240 else 0
    except Exception as e:
        print(f"Duration 변환 오류: {e}")
        return 0

def contains_korean(text):
    return bool(re.search(r"[가-힣]", text))

# 키워드 기반 영상 검색
def search_video_ids_by_keyword(keyword):
    search_url = "https://www.googleapis.com/youtube/v3/search"
    params = {
        "part": "snippet",
        "type": "video",
        "regionCode": "KR",
        "order": "viewCount",
        "maxResults": 50,
        "publishedAfter": start_date,
        "publishedBefore": end_date,
        "q": keyword,
        "relevanceLanguage": "ko",
    }
    
    video_ids = set()
    next_page_token = None
    while True:
        if next_page_token:
            params["pageToken"] = next_page_token
        response = get_valid_response(search_url, params)
        if not response:
            break
        data = response.json()
        for item in data.get("items", []):
            vid = item.get("id", {}).get("videoId")
            title = item.get("snippet", {}).get("title", "")
            if vid and contains_korean(title):
                video_ids.add(vid)
        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break
    return list(video_ids)

def get_videos_details(video_ids):
    url = "https://www.googleapis.com/youtube/v3/videos"
    all_videos = []
    for i in range(0, len(video_ids), 50):
        batch = video_ids[i:i+50]
        params = {
            "part": "snippet,statistics,contentDetails",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_videos.extend(data.get("items", []))
    return all_videos

def get_channels_info(channel_ids):
    url = "https://www.googleapis.com/youtube/v3/channels"
    all_channels = []
    channel_ids = list(channel_ids)
    for i in range(0, len(channel_ids), 50):
        batch = channel_ids[i:i+50]
        params = {
            "part": "snippet,statistics",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_channels.extend(data.get("items", []))
    return all_channels

# 전체 수집
video_data = []
channel_ids = set()

for keyword in keywords:
    print(f"키워드 '{keyword}' 수집 중...")
    video_ids = search_video_ids_by_keyword(keyword)
    print(f" - 검색된 영상 수: {len(video_ids)}")
    if not video_ids:
        continue
    videos_details = get_videos_details(video_ids)
    for video in videos_details:
        snippet = video.get("snippet", {})
        statistics = video.get("statistics", {})
        content_details = video.get("contentDetails", {})

        video_id = video.get("id")
        channel_id = snippet.get("channelId", "")
        title = snippet.get("title", "")
        view_count = int(statistics.get("viewCount", "0"))
        like_count = statistics.get("likeCount", "0")
        comment_count = statistics.get("commentCount", "0")
        upload_date = snippet.get("publishedAt", "")
        duration_sec = convert_duration_to_seconds(content_details.get("duration", "PT0S"))
        thumbnail_url = snippet.get("thumbnails", {}).get("high", {}).get("url", "")
        tags = snippet.get("tags", [])

        if duration_sec == 0:
            continue

        video_data.append([
            video_id, channel_id, title, view_count, like_count, comment_count,
            upload_date, duration_sec, tags, thumbnail_url, keyword
        ])
        channel_ids.add(channel_id)

# 채널 정보 수집
channel_data = []
channels_details = get_channels_info(channel_ids)
for channel in channels_details:
    snippet = channel.get("snippet", {})
    statistics = channel.get("statistics", {})
    channel_data.append([
        channel.get("id"), snippet.get("title", ""), statistics.get("subscriberCount", "0"),
        statistics.get("viewCount", "0"), statistics.get("videoCount", "0")
    ])

# 저장
df_videos = pd.DataFrame(video_data, columns=["videoID", "channelID", "title", "viewCount", "likeCount", "commentCount", "uploadDate", "duration", "tags", "thumbnailURL", "keyword"])
df_videos.to_csv("videos_by_keywords.csv", index=False, encoding="utf-8-sig")
print("영상 데이터 저장 완료: videos_by_keywords.csv")

df_channels = pd.DataFrame(channel_data, columns=["channelID", "channelTitle", "subscriberCount", "totalViews", "videosCount"])
df_channels.to_csv("channels_by_keywords.csv", index=False, encoding="utf-8-sig")
print("채널 데이터 저장 완료: channels_by_keywords.csv")
# Out:
# ⚡ 키워드 '건강' 수집 중...
# [!] 키 1 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 515
#
# ⚡ 키워드 '게임' 수집 중...
#  - 검색된 영상 수: 541
#
# ⚡ 키워드 '과학' 수집 중...
#  - 검색된 영상 수: 535
#
# ⚡ 키워드 '금융' 수집 중...
#  - 검색된 영상 수: 542
#
# ⚡ 키워드 '뉴스' 수집 중...
#  - 검색된 영상 수: 543
#
# ⚡ 키워드 '도서' 수집 중...
#  - 검색된 영상 수: 564
#
# ⚡ 키워드 '문학' 수집 중...
#  - 검색된 영상 수: 559
#
# ⚡ 키워드 '미용' 수집 중...
#  - 검색된 영상 수: 557
#
# ⚡ 키워드 '부동산' 수집 중...
# [!] 키 2 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 544
#
# ⚡ 키워드 '비즈니스' 수집 중...
#  - 검색된 영상 수: 365
#
# ⚡ 키워드 '산업' 수집 중...
#  - 검색된 영상 수: 541
#
# ⚡ 키워드 '사법' 수집 중...
#  - 검색된 영상 수: 532
#
# ⚡ 키워드 '정부기관' 수집 중...
#  - 검색된 영상 수: 41
#
# ⚡ 키워드 '쇼핑' 수집 중...
#  - 검색된 영상 수: 285
#
# ⚡ 키워드 '스포츠' 수집 중...
#  - 검색된 영상 수: 537
#
# ⚡ 키워드 '식음료' 수집 중...
#  - 검색된 영상 수: 19
#
# ⚡ 키워드 '애완동물 및 동물' 수집 중...
#  - 검색된 영상 수: 23
#
# ⚡ 키워드 '여행' 수집 중...
#  - 검색된 영상 수: 531
#
# ⚡ 키워드 '예술' 수집 중...
#  - 검색된 영상 수: 550
#
# ⚡ 키워드 '엔터테인먼트' 수집 중...
#  - 검색된 영상 수: 451
#
# ⚡ 키워드 '온라인 커뮤니티' 수집 중...
# [!] 키 3 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 22
#
# ⚡ 키워드 '인터넷' 수집 중...
#  - 검색된 영상 수: 486
#
# ⚡ 키워드 '통신' 수집 중...
#  - 검색된 영상 수: 538
#
# ⚡ 키워드 '자동차' 수집 중...
#  - 검색된 영상 수: 523
#
# ⚡ 키워드 '직업' 수집 중...
#  - 검색된 영상 수: 524
#
# ⚡ 키워드 '교육' 수집 중...
#  - 검색된 영상 수: 526
#
# ⚡ 키워드 '집단' 수집 중...
#  - 검색된 영상 수: 517
#
# ⚡ 키워드 '사회' 수집 중...
#  - 검색된 영상 수: 525
#
# ⚡ 키워드 '참고문헌' 수집 중...
#  - 검색된 영상 수: 49
#
# ⚡ 키워드 '취미' 수집 중...
#  - 검색된 영상 수: 545
#
# ⚡ 키워드 '레저' 수집 중...
# [!] 키 4 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 547
#
# ⚡ 키워드 '컴퓨터' 수집 중...
#  - 검색된 영상 수: 317
#
# ⚡ 키워드 '전자제품' 수집 중...
#  - 검색된 영상 수: 299
#
# ⚡ 키워드 '홈' 수집 중...
#  - 검색된 영상 수: 513
#
# ⚡ 키워드 '가든' 수집 중...
#  - 검색된 영상 수: 393
# 영상 데이터 저장 완료: videos_by_keywords.csv
# 채널 데이터 저장 완료: channels_by_keywords.csv

# %% [markdown]
# ### 전체 크롤링

# %%
import requests
import isodate
import os
import re
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# API 키 여러 개 로드
load_dotenv()

def load_api_keys():
    keys = []
    i = 1
    while True:
        key = os.getenv(f"API_KEY{i}")
        if key:
            keys.append(key)
            i += 1
        else:
            break
    return keys

api_keys = load_api_keys()
key_index = 0

def get_valid_response(url, params):
    global key_index
    max_attempts = len(api_keys)
    for _ in range(max_attempts):
        params["key"] = api_keys[key_index]
        response = requests.get(url, params=params)
        if response.status_code == 200:
            return response
        elif response.status_code in [403, 400]:  # 할당량 초과
            print(f"[!] 키 {key_index+1} 한도 초과. 다음 키로 전환.")
            key_index = (key_index + 1) % len(api_keys)
        else:
            print(f"[!] 기타 오류: {response.text}")
            break
    print("[X] 모든 API 키가 소진되었거나 요청 실패.")
    return None

# 날짜 설정 (최근 한 달)
current_date_obj = datetime.now(timezone.utc)
one_month_ago = current_date_obj - timedelta(days=30)
start_date = one_month_ago.isoformat()
end_date = current_date_obj.isoformat()

# 키워드 불러오기
keywords_df = pd.read_csv("유튜브 카테고리명.csv")
keywords = keywords_df['category'].dropna().unique().tolist()

# 유틸 함수
def convert_duration_to_seconds(duration):
    try:
        parsed_duration = isodate.parse_duration(duration)
        seconds = int(parsed_duration.total_seconds()) if parsed_duration else 0
        return seconds
    except Exception as e:
        print(f"Duration 변환 오류: {e}")
        return 0

def contains_korean(text):
    return bool(re.search(r"[가-힣]", text))

# 키워드 기반 영상 검색
def search_video_ids_by_keyword(keyword):
    search_url = "https://www.googleapis.com/youtube/v3/search"
    params = {
        "part": "snippet",
        "type": "video",
        "regionCode": "KR",
        "order": "viewCount",
        "maxResults": 50,
        "publishedAfter": start_date,
        "publishedBefore": end_date,
        "q": keyword,
        "relevanceLanguage": "ko",
    }
    
    video_ids = set()
    next_page_token = None
    while True:
        if next_page_token:
            params["pageToken"] = next_page_token
        response = get_valid_response(search_url, params)
        if not response:
            break
        data = response.json()
        for item in data.get("items", []):
            vid = item.get("id", {}).get("videoId")
            title = item.get("snippet", {}).get("title", "")
            if vid and contains_korean(title):
                video_ids.add(vid)
        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break
    return list(video_ids)

# 영상 상세 정보
def get_videos_details(video_ids):
    url = "https://www.googleapis.com/youtube/v3/videos"
    all_videos = []
    for i in range(0, len(video_ids), 50):
        batch = video_ids[i:i+50]
        params = {
            "part": "snippet,statistics,contentDetails",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_videos.extend(data.get("items", []))
    return all_videos

# 채널 정보
def get_channels_info(channel_ids):
    url = "https://www.googleapis.com/youtube/v3/channels"
    all_channels = []
    channel_ids = list(channel_ids)
    for i in range(0, len(channel_ids), 50):
        batch = channel_ids[i:i+50]
        params = {
            "part": "snippet,statistics",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_channels.extend(data.get("items", []))
    return all_channels

# 전체 수집
video_data = []
channel_ids = set()

for keyword in keywords:
    print(f"\n⚡ 키워드 '{keyword}' 수집 중...")
    video_ids = search_video_ids_by_keyword(keyword)
    print(f" - 검색된 영상 수: {len(video_ids)}")
    if not video_ids:
        continue
    videos_details = get_videos_details(video_ids)
    for video in videos_details:
        snippet = video.get("snippet", {})
        statistics = video.get("statistics", {})
        content_details = video.get("contentDetails", {})

        video_id = video.get("id")
        channel_id = snippet.get("channelId", "")
        title = snippet.get("title", "")
        view_count = int(statistics.get("viewCount", "0"))
        like_count = statistics.get("likeCount", "0")
        comment_count = statistics.get("commentCount", "0")
        upload_date = snippet.get("publishedAt", "")
        duration_sec = convert_duration_to_seconds(content_details.get("duration", "PT0S"))
        thumbnail_url = snippet.get("thumbnails", {}).get("high", {}).get("url", "")
        tags = snippet.get("tags", [])

        video_data.append([
            video_id, channel_id, title, view_count, like_count, comment_count,
            upload_date, duration_sec, tags, thumbnail_url, keyword
        ])
        channel_ids.add(channel_id)

# 채널 정보 수집
channel_data = []
channels_details = get_channels_info(channel_ids)
for channel in channels_details:
    snippet = channel.get("snippet", {})
    statistics = channel.get("statistics", {})
    channel_data.append([
        channel.get("id"), snippet.get("title", ""), statistics.get("subscriberCount", "0"),
        statistics.get("viewCount", "0"), statistics.get("videoCount", "0")
    ])

# 저장
df_videos = pd.DataFrame(video_data, columns=[
    "videoID", "channelID", "title", "viewCount", "likeCount", "commentCount",
    "uploadDate", "duration", "tags", "thumbnailURL", "keyword"
])
df_videos.to_csv("videos_by_keywords_전체.csv", index=False, encoding="utf-8-sig")
print("영상 데이터 저장 완료: videos_by_keywords_전체.csv")

df_channels = pd.DataFrame(channel_data, columns=[
    "channelID", "channelTitle", "subscriberCount", "totalViews", "videosCount"
])
df_channels.to_csv("channels_by_keywords_전체.csv", index=False, encoding="utf-8-sig")
print("채널 데이터 저장 완료: channels_by_keywords_전체.csv")
# Out:
# ⚡ 키워드 '건강' 수집 중...
# [!] 키 1 한도 초과. 다음 키로 전환.
# [!] 키 2 한도 초과. 다음 키로 전환.
# [!] 키 3 한도 초과. 다음 키로 전환.
# [!] 키 4 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 513
#
# ⚡ 키워드 '게임' 수집 중...
#  - 검색된 영상 수: 541
#
# ⚡ 키워드 '과학' 수집 중...
#  - 검색된 영상 수: 533
#
# ⚡ 키워드 '기술' 수집 중...
#  - 검색된 영상 수: 526
#
# ⚡ 키워드 '기후' 수집 중...
# [!] 키 5 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 549
#
# ⚡ 키워드 '금융' 수집 중...
#  - 검색된 영상 수: 533
#
# ⚡ 키워드 '뉴스' 수집 중...
#  - 검색된 영상 수: 541
#
# ⚡ 키워드 '도서' 수집 중...
#  - 검색된 영상 수: 552
#
# ⚡ 키워드 '문학' 수집 중...
#  - 검색된 영상 수: 562
#
# ⚡ 키워드 '미용' 수집 중...
#  - 검색된 영상 수: 554
#
# ⚡ 키워드 '패션' 수집 중...
#  - 검색된 영상 수: 506
#
# ⚡ 키워드 '부동산' 수집 중...
#  - 검색된 영상 수: 524
#
# ⚡ 키워드 '비즈니스' 수집 중...
#  - 검색된 영상 수: 376
#
# ⚡ 키워드 '법률' 수집 중...
# [!] 키 6 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 533
#
# ⚡ 키워드 '산업' 수집 중...
#  - 검색된 영상 수: 537
#
# ⚡ 키워드 '사법' 수집 중...
#  - 검색된 영상 수: 523
#
# ⚡ 키워드 '정부' 수집 중...
#  - 검색된 영상 수: 514
#
# ⚡ 키워드 '정치' 수집 중...
#  - 검색된 영상 수: 529
#
# ⚡ 키워드 '쇼핑' 수집 중...
#  - 검색된 영상 수: 280
#
# ⚡ 키워드 '스포츠' 수집 중...
#  - 검색된 영상 수: 515
#
# ⚡ 키워드 '식음료' 수집 중...
#  - 검색된 영상 수: 19
#
# ⚡ 키워드 '애완동물' 수집 중...
#  - 검색된 영상 수: 536
#
# ⚡ 키워드 '동물' 수집 중...
#  - 검색된 영상 수: 502
#
# ⚡ 키워드 '여행' 수집 중...
# [!] 키 7 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 509
#
# ⚡ 키워드 '예술' 수집 중...
#  - 검색된 영상 수: 555
#
# ⚡ 키워드 '엔터테인먼트' 수집 중...
#  - 검색된 영상 수: 507
#
# ⚡ 키워드 '온라인 커뮤니티' 수집 중...
#  - 검색된 영상 수: 22
#
# ⚡ 키워드 '인터넷' 수집 중...
#  - 검색된 영상 수: 484
#
# ⚡ 키워드 '통신' 수집 중...
#  - 검색된 영상 수: 542
#
# ⚡ 키워드 '자동차' 수집 중...
#  - 검색된 영상 수: 522
#
# ⚡ 키워드 '직업' 수집 중...
#  - 검색된 영상 수: 528
#
# ⚡ 키워드 '교육' 수집 중...
#  - 검색된 영상 수: 528
#
# ⚡ 키워드 '집단' 수집 중...
#  - 검색된 영상 수: 515
#
# ⚡ 키워드 '사회' 수집 중...
# [!] 키 8 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 517
#
# ⚡ 키워드 '참고문헌' 수집 중...
#  - 검색된 영상 수: 49
#
# ⚡ 키워드 '취미' 수집 중...
#  - 검색된 영상 수: 542
#
# ⚡ 키워드 '취업' 수집 중...
#  - 검색된 영상 수: 531
#
# ⚡ 키워드 '레저' 수집 중...
#  - 검색된 영상 수: 541
#
# ⚡ 키워드 '컴퓨터' 수집 중...
#  - 검색된 영상 수: 313
#
# ⚡ 키워드 '전자제품' 수집 중...
#  - 검색된 영상 수: 298
#
# ⚡ 키워드 '홈' 수집 중...
#  - 검색된 영상 수: 517
#
# ⚡ 키워드 '가든' 수집 중...
#  - 검색된 영상 수: 382
# 영상 데이터 저장 완료: videos_by_keywords_전체.csv
# 채널 데이터 저장 완료: channels_by_keywords_전체.csv

# %% [markdown]
# ### 5일씩 6회로 나누어 크롤링해보자

# %%
import requests
import isodate
import os
import re
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# API 키 여러 개 로드
load_dotenv()

def load_api_keys():
    keys = []
    i = 1
    while True:
        key = os.getenv(f"API_KEY{i}")
        if key:
            keys.append(key)
            i += 1
        else:
            break
    return keys

api_keys = load_api_keys()
key_index = 0

def get_valid_response(url, params):
    global key_index
    max_attempts = len(api_keys)
    for _ in range(max_attempts):
        params["key"] = api_keys[key_index]
        response = requests.get(url, params=params)
        if response.status_code == 200:
            return response
        elif response.status_code in [403, 400]:  # 할당량 초과
            print(f"[!] 키 {key_index+1} 한도 초과. 다음 키로 전환.")
            key_index = (key_index + 1) % len(api_keys)
        else:
            print(f"[!] 기타 오류: {response.text}")
            break
    print("[X] 모든 API 키가 소진되었거나 요청 실패.")
    return None

# 날짜 설정 (최근 한 달)
current_date_obj = datetime.now(timezone.utc)
one_month_ago = current_date_obj - timedelta(days=30)
start_date = one_month_ago.isoformat()
end_date = current_date_obj.isoformat()

# 키워드 불러오기
keywords_df = pd.read_csv("유튜브 카테고리명.csv")
keywords = keywords_df['category'].dropna().unique().tolist()

# 유틸 함수
def convert_duration_to_seconds(duration):
    try:
        parsed_duration = isodate.parse_duration(duration)
        seconds = int(parsed_duration.total_seconds()) if parsed_duration else 0
        return seconds
    except Exception as e:
        print(f"Duration 변환 오류: {e}")
        return 0

def contains_korean(text):
    return bool(re.search(r"[가-힣]", text))

# 키워드 기반 영상 검색
def search_video_ids_by_keyword(keyword):
    search_url = "https://www.googleapis.com/youtube/v3/search"
    video_ids = set()

    # 날짜 범위를 5일씩 쪼개기
    period = timedelta(days=5)
    start_dt = datetime.now(timezone.utc) - timedelta(days=30)
    end_dt = datetime.now(timezone.utc)

    while start_dt < end_dt:
        part_start = start_dt.isoformat()
        part_end = (start_dt + period).isoformat()
        print(f"- {part_start[:10]} ~ {part_end[:10]} 검색 중...")

        params = {
            "part": "snippet",
            "type": "video",
            "regionCode": "KR",
            "order": "viewCount",
            "maxResults": 50,
            "publishedAfter": part_start,
            "publishedBefore": part_end,
            "q": keyword,
            "relevanceLanguage": "ko",
        }

        next_page_token = None
        while True:
            if next_page_token:
                params["pageToken"] = next_page_token
            response = get_valid_response(search_url, params)
            if not response:
                break
            data = response.json()
            for item in data.get("items", []):
                vid = item.get("id", {}).get("videoId")
                title = item.get("snippet", {}).get("title", "")
                if vid and contains_korean(title):
                    video_ids.add(vid)
            next_page_token = data.get("nextPageToken")
            if not next_page_token:
                break

        start_dt += period  # 다음 구간으로 이동

    return list(video_ids)


# 영상 상세 정보
def get_videos_details(video_ids):
    url = "https://www.googleapis.com/youtube/v3/videos"
    all_videos = []
    for i in range(0, len(video_ids), 50):
        batch = video_ids[i:i+50]
        params = {
            "part": "snippet,statistics,contentDetails",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_videos.extend(data.get("items", []))
    return all_videos

# 채널 정보
def get_channels_info(channel_ids):
    url = "https://www.googleapis.com/youtube/v3/channels"
    all_channels = []
    channel_ids = list(channel_ids)
    for i in range(0, len(channel_ids), 50):
        batch = channel_ids[i:i+50]
        params = {
            "part": "snippet,statistics",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_channels.extend(data.get("items", []))
    return all_channels

# 전체 수집
video_data = []
channel_ids = set()

for keyword in keywords:
    print(f"\n⚡ 키워드 '{keyword}' 수집 중...")
    video_ids = search_video_ids_by_keyword(keyword)
    print(f" - 검색된 영상 수: {len(video_ids)}")
    if not video_ids:
        continue
    videos_details = get_videos_details(video_ids)
    for video in videos_details:
        snippet = video.get("snippet", {})
        statistics = video.get("statistics", {})
        content_details = video.get("contentDetails", {})

        video_id = video.get("id")
        channel_id = snippet.get("channelId", "")
        title = snippet.get("title", "")
        view_count = int(statistics.get("viewCount", "0"))
        like_count = statistics.get("likeCount", "0")
        comment_count = statistics.get("commentCount", "0")
        upload_date = snippet.get("publishedAt", "")
        duration_sec = convert_duration_to_seconds(content_details.get("duration", "PT0S"))
        thumbnail_url = snippet.get("thumbnails", {}).get("high", {}).get("url", "")
        tags = snippet.get("tags", [])

        video_data.append([
            video_id, channel_id, title, view_count, like_count, comment_count,
            upload_date, duration_sec, tags, thumbnail_url, keyword
        ])
        channel_ids.add(channel_id)

# 채널 정보 수집
channel_data = []
channels_details = get_channels_info(channel_ids)
for channel in channels_details:
    snippet = channel.get("snippet", {})
    statistics = channel.get("statistics", {})
    channel_data.append([
        channel.get("id"), snippet.get("title", ""), statistics.get("subscriberCount", "0"),
        statistics.get("viewCount", "0"), statistics.get("videoCount", "0")
    ])

# 저장
df_videos = pd.DataFrame(video_data, columns=[
    "videoID", "channelID", "title", "viewCount", "likeCount", "commentCount",
    "uploadDate", "duration", "tags", "thumbnailURL", "keyword"
])
df_videos.to_csv("videos_by_keywords_전체_2.csv", index=False, encoding="utf-8-sig")
print("영상 데이터 저장 완료: videos_by_keywords_전체_2.csv")

df_channels = pd.DataFrame(channel_data, columns=[
    "channelID", "channelTitle", "subscriberCount", "totalViews", "videosCount"
])
df_channels.to_csv("channels_by_keywords_전체_2.csv", index=False, encoding="utf-8-sig")
print("채널 데이터 저장 완료: channels_by_keywords_전체_2.csv")
# Out:
# ⚡ 키워드 '건강' 수집 중...
# - 2025-02-19 ~ 2025-02-24 검색 중...
# - 2025-02-24 ~ 2025-03-01 검색 중...
# - 2025-03-01 ~ 2025-03-06 검색 중...
# - 2025-03-06 ~ 2025-03-11 검색 중...
# - 2025-03-11 ~ 2025-03-16 검색 중...
#
# ⚡ 키워드 '레저' 수집 중...
# - 2025-02-19 ~ 2025-02-24 검색 중...
# - 2025-02-24 ~ 2025-03-01 검색 중...
# - 2025-03-01 ~ 2025-03-06 검색 중...
# - 2025-03-06 ~ 2025-03-11 검색 중...
# - 2025-03-11 ~ 2025-03-16 검색 중...
# - 2025-03-16 ~ 2025-03-21 검색 중...
#  - 검색된 영상 수: 1148
# [!] 키 18 한도 초과. 다음 키로 전환.
#
# ⚡ 키워드 '컴퓨터' 수집 중...
# - 2025-02-19 ~ 2025-02-24 검색 중...
# - 2025-02-24 ~ 2025-03-01 검색 중...
# - 2025-03-01 ~ 2025-03-06 검색 중...
# - 2025-03-06 ~ 2025-03-11 검색 중...
# - 2025-03-11 ~ 2025-03-16 검색 중...
# - 2025-03-16 ~ 2025-03-21 검색 중...
#  - 검색된 영상 수: 1999
#
# ⚡ 키워드 '전자제품' 수집 중...
# - 2025-02-19 ~ 2025-02-24 검색 중...
# - 2025-02-24 ~ 2025-03-01 검색 중...
# - 2025-03-01 ~ 2025-03-06 검색 중...
# - 2025-03-06 ~ 2025-03-11 검색 중...
# - 2025-03-11 ~ 2025-03-16 검색 중...
# - 2025-03-16 ~ 2025-03-21 검색 중...
#  - 검색된 영상 수: 1018
#
# ⚡ 키워드 '홈' 수집 중...
# - 2025-02-19 ~ 2025-02-24 검색 중...
# - 2025-02-24 ~ 2025-03-01 검색 중...
# [!] 키 19 한도 초과. 다음 키로 전환.
# - 2025-03-01 ~ 2025-03-06 검색 중...
# - 2025-03-06 ~ 2025-03-11 검색 중...
# - 2025-03-11 ~ 2025-03-16 검색 중...
# - 2025-03-16 ~ 2025-03-21 검색 중...
#  - 검색된 영상 수: 2361
#
# ⚡ 키워드 '가든' 수집 중...
# - 2025-02-19 ~ 2025-02-24 검색 중...
# - 2025-02-24 ~ 2025-03-01 검색 중...
# - 2025-03-01 ~ 2025-03-06 검색 중...
# - 2025-03-06 ~ 2025-03-11 검색 중...
# - 2025-03-11 ~ 2025-03-16 검색 중...
# - 2025-03-16 ~ 2025-03-21 검색 중...
# [!] 키 20 한도 초과. 다음 키로 전환.
#  - 검색된 영상 수: 1987
# 영상 데이터 저장 완료: videos_by_keywords_전체_2.csv
# 채널 데이터 저장 완료: channels_by_keywords_전체_2.csv

# %%
import requests
import isodate
import os
import re
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# API 키 여러 개 로드
load_dotenv()

def load_api_keys():
    keys = []
    i = 1
    while True:
        key = os.getenv(f"API_KEY{i}")
        if key:
            keys.append(key)
            i += 1
        else:
            break
    return keys

api_keys = load_api_keys()
key_index = 0

def get_valid_response(url, params):
    global key_index
    max_attempts = len(api_keys)
    for _ in range(max_attempts):
        params["key"] = api_keys[key_index]
        response = requests.get(url, params=params)
        if response.status_code == 200:
            return response
        elif response.status_code in [403, 400]:  # 할당량 초과 등
            print(f"[!] 키 {key_index+1} 한도 초과. 다음 키로 전환.")
            key_index = (key_index + 1) % len(api_keys)
        else:
            print(f"[!] 기타 오류: {response.text}")
            break
    print("[X] 모든 API 키가 소진되었거나 요청 실패.")
    return None

# 기준 날짜 설정 (UTC 기준 현재시간)
current_date_obj = datetime.now(timezone.utc)
one_month_ago = current_date_obj - timedelta(days=30)
start_date = one_month_ago.isoformat()
end_date = current_date_obj.isoformat()

# 키워드 불러오기
keywords_df = pd.read_csv("카테고리별 키워드 리스트.csv")
keywords = keywords_df['keywords'].dropna().unique().tolist()

# 유틸 함수
def convert_duration_to_seconds(duration):
    try:
        parsed_duration = isodate.parse_duration(duration)
        seconds = int(parsed_duration.total_seconds()) if parsed_duration else 0
        return seconds
    except Exception as e:
        print(f"Duration 변환 오류: {e}")
        return 0

def contains_korean(text):
    return bool(re.search(r"[가-힣]", text))

# 영상 업로드 날짜를 기반으로 구간(1~6) 할당 함수
def assign_segment(upload_date, current_date):
    try:
        # ISO 8601 형식의 문자열에서 Z를 처리
        dt = datetime.fromisoformat(upload_date.replace("Z", "+00:00"))
        # 현재와의 시간 차이를 일(day) 단위로 계산
        days_diff = (current_date - dt).total_seconds() / (3600 * 24)
        # 0~5일: 1구간, 5~10일: 2구간, ... 25~30일: 6구간
        segment = int(days_diff // 5) + 1
        return segment
    except Exception as e:
        print(f"구간 할당 오류: {e}")
        return None

# 키워드 기반 영상 검색
def search_video_ids_by_keyword(keyword):
    search_url = "https://www.googleapis.com/youtube/v3/search"
    video_ids = set()

    # 날짜 범위를 5일씩 쪼개기
    period = timedelta(days=5)
    start_dt = datetime.now(timezone.utc) - timedelta(days=30)
    end_dt = datetime.now(timezone.utc)

    while start_dt < end_dt:
        part_start = start_dt.isoformat()
        part_end = (start_dt + period).isoformat()
        print(f"- {part_start[:10]} ~ {part_end[:10]} 검색 중...")

        params = {
            "part": "snippet",
            "type": "video",
            "regionCode": "KR",
            "order": "viewCount",
            "maxResults": 50,
            "publishedAfter": part_start,
            "publishedBefore": part_end,
            "q": keyword,
            "relevanceLanguage": "ko",
        }

        next_page_token = None
        while True:
            if next_page_token:
                params["pageToken"] = next_page_token
            response = get_valid_response(search_url, params)
            if not response:
                break
            data = response.json()
            for item in data.get("items", []):
                vid = item.get("id", {}).get("videoId")
                title = item.get("snippet", {}).get("title", "")
                if vid and contains_korean(title):
                    video_ids.add(vid)
            next_page_token = data.get("nextPageToken")
            if not next_page_token:
                break

        start_dt += period  # 다음 구간으로 이동

    return list(video_ids)


# 영상 상세 정보
def get_videos_details(video_ids):
    url = "https://www.googleapis.com/youtube/v3/videos"
    all_videos = []
    for i in range(0, len(video_ids), 50):
        batch = video_ids[i:i+50]
        params = {
            "part": "snippet,statistics,contentDetails",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_videos.extend(data.get("items", []))
    return all_videos

# 채널 정보
def get_channels_info(channel_ids):
    url = "https://www.googleapis.com/youtube/v3/channels"
    all_channels = []
    channel_ids = list(channel_ids)
    for i in range(0, len(channel_ids), 50):
        batch = channel_ids[i:i+50]
        params = {
            "part": "snippet,statistics",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_channels.extend(data.get("items", []))
    return all_channels

# 전체 수집
video_data = []
channel_ids = set()
seen_video_ids = set()  # 중복 영상 체크용

for keyword in keywords:
    print(f"\n⚡ 키워드 '{keyword}' 수집 중...")
    video_ids = search_video_ids_by_keyword(keyword)
    print(f" - 검색된 영상 수: {len(video_ids)}")
    if not video_ids:
        continue
    videos_details = get_videos_details(video_ids)
    for video in videos_details:
        video_id = video.get("id")
        # 이미 저장한 영상이면 건너뜀
        if video_id in seen_video_ids:
            continue
        seen_video_ids.add(video_id)
        
        snippet = video.get("snippet", {})
        statistics = video.get("statistics", {})
        content_details = video.get("contentDetails", {})

        channel_id = snippet.get("channelId", "")
        title = snippet.get("title", "")
        view_count = int(statistics.get("viewCount", "0"))
        like_count = statistics.get("likeCount", "0")
        comment_count = statistics.get("commentCount", "0")
        upload_date = snippet.get("publishedAt", "")
        duration_sec = convert_duration_to_seconds(content_details.get("duration", "PT0S"))
        thumbnail_url = snippet.get("thumbnails", {}).get("high", {}).get("url", "")
        tags = snippet.get("tags", [])
        
        # 업로드 날짜를 기준으로 구간 할당 (최근 5일: 1구간, 그 다음 5일: 2구간, ...)
        segment = assign_segment(upload_date, current_date_obj)

        video_data.append([
            video_id, channel_id, title, view_count, like_count, comment_count,
            upload_date, duration_sec, tags, thumbnail_url, keyword, segment
        ])
        channel_ids.add(channel_id)

# 채널 정보 수집
channel_data = []
channels_details = get_channels_info(channel_ids)
seen_channel_ids = set()  # 중복 채널 체크용
for channel in channels_details:
    channel_id = channel.get("id")
    if channel_id in seen_channel_ids:
        continue
    seen_channel_ids.add(channel_id)
    
    snippet = channel.get("snippet", {})
    statistics = channel.get("statistics", {})
    channel_data.append([
        channel_id, snippet.get("title", ""), statistics.get("subscriberCount", "0"),
        statistics.get("viewCount", "0"), statistics.get("videoCount", "0")
    ])

# 저장 (영상 데이터에 segment 컬럼 추가)
df_videos = pd.DataFrame(video_data, columns=[
    "videoID", "channelID", "title", "viewCount", "likeCount", "commentCount",
    "uploadDate", "duration", "tags", "thumbnailURL", "keyword", "segment"
])
df_videos.to_csv("videos_by_keywords_전체_3.csv", index=False, encoding="utf-8-sig")
print("영상 데이터 저장 완료: videos_by_keywords_전체_3.csv")

df_channels = pd.DataFrame(channel_data, columns=[
    "channelID", "channelTitle", "subscriberCount", "totalViews", "videosCount"
])
df_channels.to_csv("channels_by_keywords_전체_3.csv", index=False, encoding="utf-8-sig")
print("채널 데이터 저장 완료: channels_by_keywords_전체_3.csv")

# %%
# 저장 (영상 데이터에 segment 컬럼 추가)
df_videos = pd.DataFrame(video_data, columns=[
    "videoID", "channelID", "title", "viewCount", "likeCount", "commentCount",
    "uploadDate", "duration", "tags", "thumbnailURL", "keyword", "segment"
])
df_videos.to_csv("videos_by_keywords_전체_3.csv", index=False, encoding="utf-8-sig")
print("영상 데이터 저장 완료: videos_by_keywords_전체_3.csv")

df_channels = pd.DataFrame(channel_data, columns=[
    "channelID", "channelTitle", "subscriberCount", "totalViews", "videosCount"
])
df_channels.to_csv("channels_by_keywords_전체_3.csv", index=False, encoding="utf-8-sig")
print("채널 데이터 저장 완료: channels_by_keywords_전체_3.csv")
# Out:
# 영상 데이터 저장 완료: videos_by_keywords_전체_3.csv
# 채널 데이터 저장 완료: channels_by_keywords_전체_3.csv

# %%
import requests
import isodate
import os
import re
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import pandas as pd

# API 키 여러 개 로드
load_dotenv()

def load_api_keys():
    keys = []
    i = 1
    while True:
        key = os.getenv(f"API_KEY{i}")
        if key:
            keys.append(key)
            i += 1
        else:
            break
    return keys

api_keys = load_api_keys()
key_index = 0

def get_valid_response(url, params):
    global key_index
    max_attempts = len(api_keys)
    for _ in range(max_attempts):
        params["key"] = api_keys[key_index]
        response = requests.get(url, params=params)
        if response.status_code == 200:
            return response
        elif response.status_code in [403, 400]:  # 할당량 초과 등
            print(f"[!] 키 {key_index+1} 한도 초과. 다음 키로 전환.")
            key_index = (key_index + 1) % len(api_keys)
        else:
            print(f"[!] 기타 오류: {response.text}")
            break
    print("[X] 모든 API 키가 소진되었거나 요청 실패.")
    return None

# 기준 날짜 설정 (UTC 기준 현재시간)
current_date_obj = datetime.now(timezone.utc)
one_month_ago = current_date_obj - timedelta(days=30)
start_date = one_month_ago.isoformat()
end_date = current_date_obj.isoformat()

# 단일 키워드 지정 ('팁')
keyword = "팁"

# 유틸 함수
def convert_duration_to_seconds(duration):
    try:
        parsed_duration = isodate.parse_duration(duration)
        seconds = int(parsed_duration.total_seconds()) if parsed_duration else 0
        return seconds
    except Exception as e:
        print(f"Duration 변환 오류: {e}")
        return 0

def contains_korean(text):
    return bool(re.search(r"[가-힣]", text))

# 영상 업로드 날짜를 기반으로 구간(1~6) 할당 함수
def assign_segment(upload_date, current_date):
    try:
        # ISO 8601 형식의 문자열에서 Z를 처리
        dt = datetime.fromisoformat(upload_date.replace("Z", "+00:00"))
        # 현재와의 시간 차이를 일(day) 단위로 계산
        days_diff = (current_date - dt).total_seconds() / (3600 * 24)
        # 0~5일: 1구간, 5~10일: 2구간, ... 25~30일: 6구간
        segment = int(days_diff // 5) + 1
        return segment
    except Exception as e:
        print(f"구간 할당 오류: {e}")
        return None

# 키워드 기반 영상 검색
def search_video_ids_by_keyword(keyword):
    search_url = "https://www.googleapis.com/youtube/v3/search"
    video_ids = set()

    # 날짜 범위를 5일씩 쪼개기
    period = timedelta(days=5)
    start_dt = datetime.now(timezone.utc) - timedelta(days=30)
    end_dt = datetime.now(timezone.utc)

    while start_dt < end_dt:
        part_start = start_dt.isoformat()
        part_end = (start_dt + period).isoformat()
        print(f"- {part_start[:10]} ~ {part_end[:10]} 검색 중...")

        params = {
            "part": "snippet",
            "type": "video",
            "regionCode": "KR",
            "order": "viewCount",
            "maxResults": 50,
            "publishedAfter": part_start,
            "publishedBefore": part_end,
            "q": keyword,
            "relevanceLanguage": "ko",
        }

        next_page_token = None
        while True:
            if next_page_token:
                params["pageToken"] = next_page_token
            response = get_valid_response(search_url, params)
            if not response:
                break
            data = response.json()
            for item in data.get("items", []):
                vid = item.get("id", {}).get("videoId")
                title = item.get("snippet", {}).get("title", "")
                if vid and contains_korean(title):
                    video_ids.add(vid)
            next_page_token = data.get("nextPageToken")
            if not next_page_token:
                break

        start_dt += period  # 다음 구간으로 이동

    return list(video_ids)

# 영상 상세 정보 조회
def get_videos_details(video_ids):
    url = "https://www.googleapis.com/youtube/v3/videos"
    all_videos = []
    for i in range(0, len(video_ids), 50):
        batch = video_ids[i:i+50]
        params = {
            "part": "snippet,statistics,contentDetails",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_videos.extend(data.get("items", []))
    return all_videos

# 채널 정보 조회
def get_channels_info(channel_ids):
    url = "https://www.googleapis.com/youtube/v3/channels"
    all_channels = []
    channel_ids = list(channel_ids)
    for i in range(0, len(channel_ids), 50):
        batch = channel_ids[i:i+50]
        params = {
            "part": "snippet,statistics",
            "id": ",".join(batch),
        }
        response = get_valid_response(url, params)
        if not response:
            continue
        data = response.json()
        all_channels.extend(data.get("items", []))
    return all_channels

# 전체 데이터 수집
video_data = []
channel_ids = set()
seen_video_ids = set()  # 중복 영상 체크용

print(f"\n⚡ 키워드 '{keyword}' 수집 중...")
video_ids = search_video_ids_by_keyword(keyword)
print(f" - 검색된 영상 수: {len(video_ids)}")
if video_ids:
    videos_details = get_videos_details(video_ids)
    for video in videos_details:
        video_id = video.get("id")
        # 중복 영상은 건너뜀
        if video_id in seen_video_ids:
            continue
        seen_video_ids.add(video_id)
        
        snippet = video.get("snippet", {})
        statistics = video.get("statistics", {})
        content_details = video.get("contentDetails", {})

        channel_id = snippet.get("channelId", "")
        title = snippet.get("title", "")
        view_count = int(statistics.get("viewCount", "0"))
        like_count = statistics.get("likeCount", "0")
        comment_count = statistics.get("commentCount", "0")
        upload_date = snippet.get("publishedAt", "")
        duration_sec = convert_duration_to_seconds(content_details.get("duration", "PT0S"))
        thumbnail_url = snippet.get("thumbnails", {}).get("high", {}).get("url", "")
        tags = snippet.get("tags", [])
        
        # 업로드 날짜 기준 구간 할당 (최근 5일: 1구간, 그 다음 5일: 2구간, ... )
        segment = assign_segment(upload_date, current_date_obj)

        video_data.append([
            video_id, channel_id, title, view_count, like_count, comment_count,
            upload_date, duration_sec, tags, thumbnail_url, keyword, segment
        ])
        channel_ids.add(channel_id)

channel_data = []
channels_details = get_channels_info(channel_ids)
seen_channel_ids = set()  # 중복 채널 체크용
for channel in channels_details:
    channel_id = channel.get("id")
    if channel_id in seen_channel_ids:
        continue
    seen_channel_ids.add(channel_id)
    
    snippet = channel.get("snippet", {})
    statistics = channel.get("statistics", {})
    channel_data.append([
        channel_id, snippet.get("title", ""), statistics.get("subscriberCount", "0"),
        statistics.get("viewCount", "0"), statistics.get("videoCount", "0")
    ])

# CSV 저장 (영상 데이터에 segment 컬럼 포함)
df_videos = pd.DataFrame(video_data, columns=[
    "videoID", "channelID", "title", "viewCount", "likeCount", "commentCount",
    "uploadDate", "duration", "tags", "thumbnailURL", "keyword", "segment"
])
df_videos.to_csv("videos_by_keyword_팁.csv", index=False, encoding="utf-8-sig")
print("영상 데이터 저장 완료: videos_by_keyword_팁.csv")

df_channels = pd.DataFrame(channel_data, columns=[
    "channelID", "channelTitle", "subscriberCount", "totalViews", "videosCount"
])
df_channels.to_csv("channels_by_keyword_팁.csv", index=False, encoding="utf-8-sig")
print("채널 데이터 저장 완료: channels_by_keyword_팁.csv")
# Out:
# ⚡ 키워드 '팁' 수집 중...
# - 2025-02-20 ~ 2025-02-25 검색 중...
# [!] 키 1 한도 초과. 다음 키로 전환.
# [!] 키 2 한도 초과. 다음 키로 전환.
# [!] 키 3 한도 초과. 다음 키로 전환.
# [!] 키 4 한도 초과. 다음 키로 전환.
# [!] 키 5 한도 초과. 다음 키로 전환.
# [!] 키 6 한도 초과. 다음 키로 전환.
# [!] 키 7 한도 초과. 다음 키로 전환.
# [!] 키 8 한도 초과. 다음 키로 전환.
# [!] 키 9 한도 초과. 다음 키로 전환.
# [!] 키 10 한도 초과. 다음 키로 전환.
# [!] 키 11 한도 초과. 다음 키로 전환.
# [!] 키 12 한도 초과. 다음 키로 전환.
# [!] 키 13 한도 초과. 다음 키로 전환.
# [!] 키 14 한도 초과. 다음 키로 전환.
# [!] 키 15 한도 초과. 다음 키로 전환.
# [!] 키 16 한도 초과. 다음 키로 전환.
# [!] 키 17 한도 초과. 다음 키로 전환.
# [!] 키 18 한도 초과. 다음 키로 전환.
# [!] 키 19 한도 초과. 다음 키로 전환.
# [!] 키 20 한도 초과. 다음 키로 전환.
# [!] 키 21 한도 초과. 다음 키로 전환.
# [!] 키 22 한도 초과. 다음 키로 전환.
# [!] 키 23 한도 초과. 다음 키로 전환.
# [!] 키 24 한도 초과. 다음 키로 전환.
# [!] 키 25 한도 초과. 다음 키로 전환.
# [!] 키 26 한도 초과. 다음 키로 전환.
# [!] 키 27 한도 초과. 다음 키로 전환.
# [!] 키 28 한도 초과. 다음 키로 전환.
# [!] 키 29 한도 초과. 다음 키로 전환.
# [!] 키 30 한도 초과. 다음 키로 전환.
# [!] 키 31 한도 초과. 다음 키로 전환.
# [!] 키 32 한도 초과. 다음 키로 전환.
# [!] 키 33 한도 초과. 다음 키로 전환.
# [!] 키 34 한도 초과. 다음 키로 전환.
# [!] 키 35 한도 초과. 다음 키로 전환.
# [!] 키 36 한도 초과. 다음 키로 전환.
# [!] 키 37 한도 초과. 다음 키로 전환.
# [!] 키 38 한도 초과. 다음 키로 전환.
# [!] 키 39 한도 초과. 다음 키로 전환.
# [!] 키 40 한도 초과. 다음 키로 전환.
# [!] 키 41 한도 초과. 다음 키로 전환.
# [!] 키 42 한도 초과. 다음 키로 전환.
# [!] 키 43 한도 초과. 다음 키로 전환.
# [!] 키 44 한도 초과. 다음 키로 전환.
# [!] 키 45 한도 초과. 다음 키로 전환.
# [!] 키 46 한도 초과. 다음 키로 전환.
# - 2025-02-25 ~ 2025-03-02 검색 중...
# - 2025-03-02 ~ 2025-03-07 검색 중...
# - 2025-03-07 ~ 2025-03-12 검색 중...
# - 2025-03-12 ~ 2025-03-17 검색 중...
# - 2025-03-17 ~ 2025-03-22 검색 중...
#  - 검색된 영상 수: 1770
# 영상 데이터 저장 완료: videos_by_keyword_팁.csv
# 채널 데이터 저장 완료: channels_by_keyword_팁.csv
